# %%
import polars as pl

# %%
file = "./datasets/yrbs/national_yrbs.parquet"
yrbs_df = pl.read_parquet(file)
yrbs_df
# Out:
# shape: (254_675, 121)
# ┌──────────┬─────────┬────────┬──────────┬───┬──────────────┬──────────────┬─────────────┬─────────┐
# │ weight   ┆ stratum ┆ PSU    ┆ sitecode ┆ … ┆ qnunfairlyac ┆ qnunfairlydi ┆ qnverbalabu ┆ qnwater │
# │ ---      ┆ ---     ┆ ---    ┆ ---      ┆   ┆ e            ┆ sc           ┆ seace       ┆ ---     │
# │ f64      ┆ i64     ┆ i64    ┆ str      ┆   ┆ ---          ┆ ---          ┆ ---         ┆ f64     │
# │          ┆         ┆        ┆          ┆   ┆ f64          ┆ f64          ┆ f64         ┆         │
# ╞══════════╪═════════╪════════╪══════════╪═══╪══════════════╪══════════════╪═════════════╪═════════╡
# │ 0.506019 ┆ 12310   ┆ 29     ┆ XX       ┆ … ┆ null         ┆ null         ┆ null        ┆ null    │
# │ 0.264458 ┆ 12210   ┆ 5      ┆ XX       ┆ … ┆ null         ┆ null         ┆ null        ┆ null    │
# │ 0.320097 ┆ 11400   ┆ 33     ┆ XX       ┆ … ┆ null         ┆ null         ┆ null        ┆ null    │
# ...

# %%
yrbs_df.columns
# Out:
# ['weight',
#  'stratum',
#  'PSU',
#  'sitecode',
#  'sitename',
#  'sitetype',
#  'year',
#  'age',
#  'sex',
#  'race',
#  'race7',
#  'grade',
#  'obese',
#  'overweight',
#  'sexuality',
#  'condensed_sexuality',
#  'sexual_partners',
#  'condensed_sexual_partners',
#  'seatbelt_qn8',
#  'ridedriverdrink_qn9',
#  'drinkdrive_qn10',
#  'textdrive_qn11',
#  'carryweaponschool_qn12',
#  'carrygun_qn13',
#  'safetyconcernschool_qn14',
#  'threatenedatschool_qn15',
#  'fight_qn16',
#  'fight_at_school_qn17',
#  'neighborhoodviolence_qn18',
#  'forcedsex_qn19',
#  'sexviolence_qn20',
#  'datingsexviolence_qn21',
#  'datingphysicalviolence_qn22',
#  'racism_qn23',
#  'bulliedatschool_qn24',
#  'ebullied_qn25',
#  'sad_qn26',
#  'thinksuicide_qn27',
#  'plansuicide_qn28',
#  'suicideatt_qn29',
#  'suicideattinjury_qn30',
#  'smokeever_qn31',
#  'agefirstsmoke_qn32',
#  'currentlysmoke_qn33',
#  'dailycigarettes_qn34',
#  'vapeever_qn35',
#  'vapecurrently_qn36',
#  'purchasedvape_qn37',
# ...
